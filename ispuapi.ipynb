# %%
def rmsimilar(data):
    d = [] # set new empty list
    for x in data:
        if x not in d: # if data never in d before
            d.append(x)
    return d

def datacleaner(data):
    d = []
    for x in range(len(data)):
        if 'Tabel Konsentrasi Partikulat' in data:
            d.append(data[x])

# %%
import ispuapi.ispuapi as api
import string


data = api.getdatabmkg()

#for x in range(len(data[52])):
#    print x, data[52].split()[x]

def rmpnct(d):
    n = []
    for x in d:
        if x in string.letters:
            n.append(x)
    return ''.join(n)

print rmpnct(data[26].split()[5])
print rmpnct(data[39].split()[5])
print rmpnct(data[52].split()[5])
print data[39]
# Out:
# Medan
# Pekanbaru
# Jambi
#
#
#
# ×
# Tabel Konsentrasi Partikulat di Pekanbaru, Tanggal :  02 November 2015
#
#
# PEKANBARU, Jam 0 : 43.96
# PEKANBARU, Jam 1 : 43.54
# PEKANBARU, Jam 2 : 44.72
# PEKANBARU, Jam 3 : 46.97
# PEKANBARU, Jam 4 : 44.08
# PEKANBARU, Jam 5 : 38.58
# PEKANBARU, Jam 6 : 50.26
# PEKANBARU, Jam 7 : 50.22
# , Jam 8 : 0.00
#
#
# Tutup

# %%
import lib.ispuapi as api

data = api.getdata('http://www.bmkg.go.id')
data = data['bmkg']

for x in range(len(data)):
    print x, data[x]
# Out:
# 0
#
#
#
#
#
# Kamis, 12 November 2015
#
# Beranda
# Peta Situs
# Kontak Kami
#
#
#
#
#
#
#
#
#
#
#
#
# BADAN METEOROLOGI, KLIMATOLOGI, DAN GEOFISIKA
# BMKG
# Cepat, Tepat, Akurat, Luas dan Mudah dipahami
#
#
#
#
# 1
#
#
#
# Kamis, 12 November 2015
#
# Beranda
# Peta Situs
# Kontak Kami
#
#
#
#
# 2
#
#
# Kamis, 12 November 2015
#
# Beranda
# Peta Situs
# Kontak Kami
#
#
#
# 3
#
# Kamis, 12 November 2015
#
# Beranda
# Peta Situs
# Kontak Kami
#
#
# 4
#
#
#
#
#
#
#
# BADAN METEOROLOGI, KLIMATOLOGI, DAN GEOFISIKA
# BMKG
# Cepat, Tepat, Akurat, Luas dan Mudah dipahami
#
#
#
# 5
#
#
#
#
# 6
#
#
# 7
#
# BADAN METEOROLOGI, KLIMATOLOGI, DAN GEOFISIKA
# BMKG
# Cepat, Tepat, Akurat, Luas dan Mudah dipahami
#
#
# 8
# BADAN METEOROLOGI, KLIMATOLOGI, DAN GEOFISIKA
# BMKG
# Cepat, Tepat, Akurat, Luas dan Mudah dipahami
#
# 9
#
#
#
#
# Toggle navigation
#
#
#
#
#
#
#
#
#
#
# ProfilSejarahVisi dan MisiTugas dan FungsiStruktur OrganisasiPejabat BMKG PusatBalai Besar MKGAlamat StasiunLogo BMKGSumber Daya ManusiaRegulasiProduk HukumPublikasiSiaran PersPidato KaBMKGArtikelMajalahAudio dan VideoJurnalE-LearningBrosur / Leaflet / BookletInformasi PublikBerkalaSetiap SaatSerta MertaDIPARencana StrategisRencana KerjaLaporan KeuanganDokumen KinerjaLayanan Informasi PublikLayanan PublikUnit Pelayanan PublikLPSEPengaduan MasyarakatForm Permintaan Informasi PublikSMSMedia SosialLinksEmail BMKGKementrian / Lembaga TerkaitLembaga InternasionalE-KlippingPerpustakaanPengumumanBeasiswaDiklat PegawaiLowongan Kerja Luar NegeriPengumuman Pegawai
#
#
#
#
#
# 10
#
#
# Toggle navigation
#
#
#
#
#
#
#
#
#
#
# ProfilSejarahVisi dan MisiTugas dan FungsiStruktur OrganisasiPejabat BMKG PusatBalai Besar MKGAlamat StasiunLogo BMKGSumber Daya ManusiaRegulasiProduk HukumPublikasiSiaran PersPidato KaBMKGArtikelMajalahAudio dan VideoJurnalE-LearningBrosur / Leaflet / BookletInformasi PublikBerkalaSetiap SaatSerta MertaDIPARencana StrategisRencana KerjaLaporan KeuanganDokumen KinerjaLayanan Informasi PublikLayanan PublikUnit Pelayanan PublikLPSEPengaduan MasyarakatForm Permintaan Informasi PublikSMSMedia SosialLinksEmail BMKGKementrian / Lembaga TerkaitLembaga InternasionalE-KlippingPerpustakaanPengumumanBeasiswaDiklat PegawaiLowongan Kerja Luar NegeriPengumuman Pegawai
#
#
#
# 11
#
# Toggle navigation
#
#
#
#
#
#
#
# 12
#
#
# ProfilSejarahVisi dan MisiTugas dan FungsiStruktur OrganisasiPejabat BMKG PusatBalai Besar MKGAlamat StasiunLogo BMKGSumber Daya ManusiaRegulasiProduk HukumPublikasiSiaran PersPidato KaBMKGArtikelMajalahAudio dan VideoJurnalE-LearningBrosur / Leaflet / BookletInformasi PublikBerkalaSetiap SaatSerta MertaDIPARencana StrategisRencana KerjaLaporan KeuanganDokumen KinerjaLayanan Informasi PublikLayanan PublikUnit Pelayanan PublikLPSEPengaduan MasyarakatForm Permintaan Informasi PublikSMSMedia SosialLinksEmail BMKGKementrian / Lembaga TerkaitLembaga InternasionalE-KlippingPerpustakaanPengumumanBeasiswaDiklat PegawaiLowongan Kerja Luar NegeriPengumuman Pegawai
#
#
# 13
# 14
#
#
#
#
# Toggle navigation
#
#
#
#
#
#
#
# Informasi CuacaPrakiraan CuacaPrakiraan Cuaca DuniaPrakiraan Cuaca IndonesiaPrakiraan Cuaca PropinsiPrakiraan Cuaca JABODETABEKProspek CuacaProspek Cuaca Tiga HarianProspek Cuaca MingguanPengindraan JauhCitra SatelitCitra RadarCuaca PenerbanganLaporan Cuaca Aktual BandaraPrakiraan Cuaca BandaraInformasi SelengkapnyaMaritim / Cuaca PelayaranPrakiraan Cuaca Untuk PelayaranPrakiraan Tinggi GelombangPrakiraan Cuaca PelabuhanPrakiraan Wilayah PerairanPrakiraan Jalur PenyebranganInformasi SelengkapnyaPrakiraan AnginPotensi Banjir Jakarta (Harian)Kebakaran HutanSiklon TropisInformasi IklimPrakiraan IklimInformasi Hujan BulananPrakiraan Hujan BulananPrakiraan MusimOutlook El NinoInformasi Hari Tanpa HujanNeraca AirDinamika AtmosfirPotensi BanjirAnalisa Kejadian Iklim EkstrimIndeks Presipitasi TerstandarisasiInformasi Suhu Muka LautInformasi Index El NinoInformasi Temperatur Subsurface PasifikInformasi Perubahan IklimInformasi Trend Curah HujanInformasi Trend SuhuInformasi Perubahan Normal Curah HujanInformasi Indeks Ekstrim Perubahan IklimInformasi Proyeksi Perubahan IklimInformasi Buku  Perubahan IklimKualitas UdaraInformasi SO2Informasi NO2Informasi SPMInformasi Kimia Air HujanInformasi Ozon (O3)Informasi Gas Rumah KacaInformasi Partikulat (PM10)Gempabumi & TsunamiGempabumiGempabumi Terkini > 5.0 SRGempabumi DirasakanAntisipasi GempabumiSkala MMIData GempaJaringan Stasiun GempabumiTsunamiSeismologi TeknikSeismologi TeknikGeopotensialGaya BeratTanda WaktuTerbit Terbenam MatahariMagnet BumiPetir (JABODETABEK)IT & Sarana TeknisInstrumentasi, Rekayasa dan KalibrasiInstrumentasiPeta Instrumentasi BMKGJaringan KomunikasiDatabase
#
#
#
#
# 15
#
#
# Toggle navigation
#
#
#
#
#
#
#
# Informasi CuacaPrakiraan CuacaPrakiraan Cuaca DuniaPrakiraan Cuaca IndonesiaPrakiraan Cuaca PropinsiPrakiraan Cuaca JABODETABEKProspek CuacaProspek Cuaca Tiga HarianProspek Cuaca MingguanPengindraan JauhCitra SatelitCitra RadarCuaca PenerbanganLaporan Cuaca Aktual BandaraPrakiraan Cuaca BandaraInformasi SelengkapnyaMaritim / Cuaca PelayaranPrakiraan Cuaca Untuk PelayaranPrakiraan Tinggi GelombangPrakiraan Cuaca PelabuhanPrakiraan Wilayah PerairanPrakiraan Jalur PenyebranganInformasi SelengkapnyaPrakiraan AnginPotensi Banjir Jakarta (Harian)Kebakaran HutanSiklon TropisInformasi IklimPrakiraan IklimInformasi Hujan BulananPrakiraan Hujan BulananPrakiraan MusimOutlook El NinoInformasi Hari Tanpa HujanNeraca AirDinamika AtmosfirPotensi BanjirAnalisa Kejadian Iklim EkstrimIndeks Presipitasi TerstandarisasiInformasi Suhu Muka LautInformasi Index El NinoInformasi Temperatur Subsurface PasifikInformasi Perubahan IklimInformasi Trend Curah HujanInformasi Trend SuhuInformasi Perubahan Normal Curah HujanInformasi Indeks Ekstrim Perubahan IklimInformasi Proyeksi Perubahan IklimInformasi Buku  Perubahan IklimKualitas UdaraInformasi SO2Informasi NO2Informasi SPMInformasi Kimia Air HujanInformasi Ozon (O3)Informasi Gas Rumah KacaInformasi Partikulat (PM10)Gempabumi & TsunamiGempabumiGempabumi Terkini > 5.0 SRGempabumi DirasakanAntisipasi GempabumiSkala MMIData GempaJaringan Stasiun GempabumiTsunamiSeismologi TeknikSeismologi TeknikGeopotensialGaya BeratTanda WaktuTerbit Terbenam MatahariMagnet BumiPetir (JABODETABEK)IT & Sarana TeknisInstrumentasi, Rekayasa dan KalibrasiInstrumentasiPeta Instrumentasi BMKGJaringan KomunikasiDatabase
#
#
#
# 16
#
# Toggle navigation
#
#
#
#
#
# 17
#
# Informasi CuacaPrakiraan CuacaPrakiraan Cuaca DuniaPrakiraan Cuaca IndonesiaPrakiraan Cuaca PropinsiPrakiraan Cuaca JABODETABEKProspek CuacaProspek Cuaca Tiga HarianProspek Cuaca MingguanPengindraan JauhCitra SatelitCitra RadarCuaca PenerbanganLaporan Cuaca Aktual BandaraPrakiraan Cuaca BandaraInformasi SelengkapnyaMaritim / Cuaca PelayaranPrakiraan Cuaca Untuk PelayaranPrakiraan Tinggi GelombangPrakiraan Cuaca PelabuhanPrakiraan Wilayah PerairanPrakiraan Jalur PenyebranganInformasi SelengkapnyaPrakiraan AnginPotensi Banjir Jakarta (Harian)Kebakaran HutanSiklon TropisInformasi IklimPrakiraan IklimInformasi Hujan BulananPrakiraan Hujan BulananPrakiraan MusimOutlook El NinoInformasi Hari Tanpa HujanNeraca AirDinamika AtmosfirPotensi BanjirAnalisa Kejadian Iklim EkstrimIndeks Presipitasi TerstandarisasiInformasi Suhu Muka LautInformasi Index El NinoInformasi Temperatur Subsurface PasifikInformasi Perubahan IklimInformasi Trend Curah HujanInformasi Trend SuhuInformasi Perubahan Normal Curah HujanInformasi Indeks Ekstrim Perubahan IklimInformasi Proyeksi Perubahan IklimInformasi Buku  Perubahan IklimKualitas UdaraInformasi SO2Informasi NO2Informasi SPMInformasi Kimia Air HujanInformasi Ozon (O3)Informasi Gas Rumah KacaInformasi Partikulat (PM10)Gempabumi & TsunamiGempabumiGempabumi Terkini > 5.0 SRGempabumi DirasakanAntisipasi GempabumiSkala MMIData GempaJaringan Stasiun GempabumiTsunamiSeismologi TeknikSeismologi TeknikGeopotensialGaya BeratTanda WaktuTerbit Terbenam MatahariMagnet BumiPetir (JABODETABEK)IT & Sarana TeknisInstrumentasi, Rekayasa dan KalibrasiInstrumentasiPeta Instrumentasi BMKGJaringan KomunikasiDatabase
#
#
# 18
#
#
# Tanda Waktu
#
#
#
#
#
# 					new showLocalTime("timecontainer", "server-asp", 0, "short")
#
#
#
# 					  sumber : Standar waktu Indonesia
#
# 					  ntp.bmkg.go.id / jam.bmkg.go.id
#
#
#
#
#
# Peringatan Dini
#
#
#
#
# 12/11/2015, 12:11:55 WIB
#   Gempa Dirasakan
#   Terjadi Gempa Dirasakan, Pusat gempa berada di darat 11 km BaratLaut Kab. Sukabumi Jabar, Mag 4.8 SR, Waktu 12/11/2015 19:07:21 WIB, dirasakan di Sukabumi II MMI, Bandung II MMI, Bogor II MMI, Jakarta II MMI
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Riau
#      Waspada Hujan Lebat Tiba-tiba Yang Disertai Petir Dan Angin Kencang
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Kalimantan Barat
#      Waspada Hujan Yang Terjadi Berpotensi Disertai Angin Kencang Dan Guntur
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Bali
#      Perlu Diwaspadai Potensi Hujan Dengan Intensitas Sedang Disertai Kilat/petir
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Dengan Intensitas Sedang-lebat Yang Disertai Kilat/petir Yang Disertai Angin Kencang Berdurasi Singkat Pada Siang-sore Hari
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Sedang-lebat Yang Disertai Kilat/petir Dan Angin Kencang Pada Siang-sore Hari
#
# Selengkapnya
#
#
#
#
#
# Prakiraan Cuaca
#
#
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
#
# Selengkapnya
#
#
#
# Informasi Iklim
#
#
#
#  Selengkapnya
#
#
#
# Gempabumi Terkini
#
# 12 November 2015 - 06:36:18 WIB
#
#
#
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# Selengkapnya
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# KULIAH UMUM RISET DAN PENGABDIAN MASYARAKAT
#
#
#
#
#
# Jumpa Pers Awal Musim Hujan `NOVEMBER, AWAL MUSIM HUJAN AKAN TIBA`
#
#
#
#
#
# WORKSHOP OPERASIONAL RADAR CUACA TAHUN 2015
#
#
#
#
#
# SEMANGAT KEPAHLAWANAN ADALAH JIWA RAGAKU
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# BERITA FOTO
#
#
#
#
#
#
# PERESMIAN BEROPERASINYA DIGITAL VIDEO BROADCAST  DI KABUPATEN SIJUNJUNG  SUMATERA BARAT
# Sijunjung, (9/11), Sebagai tindak lanjut MoU (Memorandum of Understanding) antara BMKG dengan  ...
#
#
#
#
#
#
#
# SEMINAR BULETIN MKG 2015
# TANGERANG - Selasa (3/11) bertempat di kantor BBMKG Wilayah II diadakan kegiatan SEMINAR BULETIN  ...
#
#
#
#
#
#
#
# KEPALA BMKG HADIRI PENGUKUHAN SESTAMA BMKG DI LEMHANNAS RI
# JAKARTA, Kamis(5/11/2015) - Upacara yang diikuti oleh 80 peserta Program Pendidikan Singkat  ...
#
#
# Indeks Berita
#
#
#
# ARTIKEL
#
#
#
# Mengukur Perubahan Ketebalan Lapisan Es di Puncak Soemantri, Papua New
# DYAH LUKITA SARI, S.Si, dkkPeneliti Muda Bidang Litbang Klimatologi dan Kualitas Udara BMKG
#
#
#
#
# Pemodelan Tiga Dimensi Anomali Gravitasi dan Identifikasi Sesar Lokal dalam Penentuan Jenis Sesar di Daerah Sidoarjo New
# ALEXANDER FELIX TAUFAN PARERA, dkkSPT. PMG Pelaksana Sta. Geof. Kelas III Kepahiang - Bengkulu BMKG
#
#
#
#
# Analisis Banjir Kab. Aceh Selatan
# SYAHRIRPMG Pelaksana Sta. Met. Kelas I Blang Bintang - Banda Aceh BMKG
#
#
#
#
# Memahami El Nino Secara Utuh
# WANDAYANTOLIS, S.Si., M.SiKepala Seksi Data dan Informasi Sta. Klim. Kelas I Kediri - Mataram BMKG
#
#
#
#
#
#
#
#
#
#
#           Prakiraan Cuaca
#
#
#
#
#
#
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
# Selengkapnya
#
#
#
#
#
#
#
#           Informasi Iklim
#
#
#
#
#
#
#
#  Selengkapnya
#
#
#
#
#
#
#
#           Informasi Gempabumi
#
#
#
#
#
# 12 November 2015 - 06:36:18 WIB
#
#
#
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# Selengkapnya
#
#
#
#
#
#
#
#
# Banner Layanan
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
#
#
#
#
#
#
#
#
#
#
# Media
#
# Rabu, 02 September 2015
# Tutorial Login ePUPNS
#
#
#
# 			jwplayer("myElement").setup({
# 			  file: "http://media.bmkg.go.id/media/LOGIN_ePUPNS_20159210290.mp4",
# 			  image: "http://media.bmkg.go.id/imagesdata/BMKG-VOD_20159211117.jpg",
# 			  width: "100%",
# 			  aspectratio: "16:9"
# 			});
#
# Tutorial Login  ...   [46.82 MB]
#
#
#
# Pidato Kepala BMKG
#
#
#
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 12/05
#
#
#
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 23/03
#
#
#
# IPCC Regional Outreach Working Group II And III  ...
# 11/07
#
#
#
# Pembukaan Rapat Rekonsiliasi Laporan Keuangan  ...
# 05/07
#
#
#
#
#
# Pengumuman
#
#
#
#
# Vacancy Notice No.1942 WMO
#
#
#
#
# Beasiswa S2 dan S3 NOAA
#
#
#
#
# Vacancy Notice No. 1941 WMO
#
#
#
# Indeks Pengumuman
#
#
#
#
# 19
#
# Tanda Waktu
#
#
#
#
#
# 					new showLocalTime("timecontainer", "server-asp", 0, "short")
#
#
#
# 					  sumber : Standar waktu Indonesia
#
# 					  ntp.bmkg.go.id / jam.bmkg.go.id
#
#
#
#
#
# Peringatan Dini
#
#
#
#
# 12/11/2015, 12:11:55 WIB
#   Gempa Dirasakan
#   Terjadi Gempa Dirasakan, Pusat gempa berada di darat 11 km BaratLaut Kab. Sukabumi Jabar, Mag 4.8 SR, Waktu 12/11/2015 19:07:21 WIB, dirasakan di Sukabumi II MMI, Bandung II MMI, Bogor II MMI, Jakarta II MMI
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Riau
#      Waspada Hujan Lebat Tiba-tiba Yang Disertai Petir Dan Angin Kencang
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Kalimantan Barat
#      Waspada Hujan Yang Terjadi Berpotensi Disertai Angin Kencang Dan Guntur
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Bali
#      Perlu Diwaspadai Potensi Hujan Dengan Intensitas Sedang Disertai Kilat/petir
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Dengan Intensitas Sedang-lebat Yang Disertai Kilat/petir Yang Disertai Angin Kencang Berdurasi Singkat Pada Siang-sore Hari
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Sedang-lebat Yang Disertai Kilat/petir Dan Angin Kencang Pada Siang-sore Hari
#
# Selengkapnya
#
#
#
#
#
# Prakiraan Cuaca
#
#
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
#
# Selengkapnya
#
#
#
# Informasi Iklim
#
#
#
#  Selengkapnya
#
#
#
# Gempabumi Terkini
#
# 12 November 2015 - 06:36:18 WIB
#
#
#
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# Selengkapnya
#
#
#
# 20
# Tanda Waktu
#
#
#
#
#
# 					new showLocalTime("timecontainer", "server-asp", 0, "short")
#
#
#
# 					  sumber : Standar waktu Indonesia
#
# 					  ntp.bmkg.go.id / jam.bmkg.go.id
#
#
#
#
# 21 Tanda Waktu
# 22
#
#
#
#
# 					new showLocalTime("timecontainer", "server-asp", 0, "short")
#
#
#
# 					  sumber : Standar waktu Indonesia
#
# 					  ntp.bmkg.go.id / jam.bmkg.go.id
#
#
#
# 23
#
#
#
# 					new showLocalTime("timecontainer", "server-asp", 0, "short")
#
#
#
# 					  sumber : Standar waktu Indonesia
#
# 					  ntp.bmkg.go.id / jam.bmkg.go.id
#
#
# 24
#
#
# 					new showLocalTime("timecontainer", "server-asp", 0, "short")
#
#
# 25
# 					  sumber : Standar waktu Indonesia
#
# 					  ntp.bmkg.go.id / jam.bmkg.go.id
#
# 26
# Peringatan Dini
#
#
#
#
# 12/11/2015, 12:11:55 WIB
#   Gempa Dirasakan
#   Terjadi Gempa Dirasakan, Pusat gempa berada di darat 11 km BaratLaut Kab. Sukabumi Jabar, Mag 4.8 SR, Waktu 12/11/2015 19:07:21 WIB, dirasakan di Sukabumi II MMI, Bandung II MMI, Bogor II MMI, Jakarta II MMI
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Riau
#      Waspada Hujan Lebat Tiba-tiba Yang Disertai Petir Dan Angin Kencang
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Kalimantan Barat
#      Waspada Hujan Yang Terjadi Berpotensi Disertai Angin Kencang Dan Guntur
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Bali
#      Perlu Diwaspadai Potensi Hujan Dengan Intensitas Sedang Disertai Kilat/petir
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Dengan Intensitas Sedang-lebat Yang Disertai Kilat/petir Yang Disertai Angin Kencang Berdurasi Singkat Pada Siang-sore Hari
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Sedang-lebat Yang Disertai Kilat/petir Dan Angin Kencang Pada Siang-sore Hari
#
# Selengkapnya
#
#
#
#
# 27 Peringatan Dini
# 28
#
#
#
# 12/11/2015, 12:11:55 WIB
#   Gempa Dirasakan
#   Terjadi Gempa Dirasakan, Pusat gempa berada di darat 11 km BaratLaut Kab. Sukabumi Jabar, Mag 4.8 SR, Waktu 12/11/2015 19:07:21 WIB, dirasakan di Sukabumi II MMI, Bandung II MMI, Bogor II MMI, Jakarta II MMI
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Riau
#      Waspada Hujan Lebat Tiba-tiba Yang Disertai Petir Dan Angin Kencang
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Kalimantan Barat
#      Waspada Hujan Yang Terjadi Berpotensi Disertai Angin Kencang Dan Guntur
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Bali
#      Perlu Diwaspadai Potensi Hujan Dengan Intensitas Sedang Disertai Kilat/petir
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Dengan Intensitas Sedang-lebat Yang Disertai Kilat/petir Yang Disertai Angin Kencang Berdurasi Singkat Pada Siang-sore Hari
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Sedang-lebat Yang Disertai Kilat/petir Dan Angin Kencang Pada Siang-sore Hari
#
# Selengkapnya
#
#
#
# 29
#
#
# 12/11/2015, 12:11:55 WIB
#   Gempa Dirasakan
#   Terjadi Gempa Dirasakan, Pusat gempa berada di darat 11 km BaratLaut Kab. Sukabumi Jabar, Mag 4.8 SR, Waktu 12/11/2015 19:07:21 WIB, dirasakan di Sukabumi II MMI, Bandung II MMI, Bogor II MMI, Jakarta II MMI
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Riau
#      Waspada Hujan Lebat Tiba-tiba Yang Disertai Petir Dan Angin Kencang
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Kalimantan Barat
#      Waspada Hujan Yang Terjadi Berpotensi Disertai Angin Kencang Dan Guntur
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Bali
#      Perlu Diwaspadai Potensi Hujan Dengan Intensitas Sedang Disertai Kilat/petir
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Dengan Intensitas Sedang-lebat Yang Disertai Kilat/petir Yang Disertai Angin Kencang Berdurasi Singkat Pada Siang-sore Hari
#
# Selengkapnya
#
#
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Sedang-lebat Yang Disertai Kilat/petir Dan Angin Kencang Pada Siang-sore Hari
#
# Selengkapnya
#
#
# 30
#
# 12/11/2015, 12:11:55 WIB
#   Gempa Dirasakan
#   Terjadi Gempa Dirasakan, Pusat gempa berada di darat 11 km BaratLaut Kab. Sukabumi Jabar, Mag 4.8 SR, Waktu 12/11/2015 19:07:21 WIB, dirasakan di Sukabumi II MMI, Bandung II MMI, Bogor II MMI, Jakarta II MMI
#
# Selengkapnya
#
# 31
# 12/11/2015, 12:11:55 WIB
#   Gempa Dirasakan
#   Terjadi Gempa Dirasakan, Pusat gempa berada di darat 11 km BaratLaut Kab. Sukabumi Jabar, Mag 4.8 SR, Waktu 12/11/2015 19:07:21 WIB, dirasakan di Sukabumi II MMI, Bandung II MMI, Bogor II MMI, Jakarta II MMI
#
# 32
#
# 13 November 2015
# Propinsi Riau
#      Waspada Hujan Lebat Tiba-tiba Yang Disertai Petir Dan Angin Kencang
#
# Selengkapnya
#
# 33
# 13 November 2015
# Propinsi Riau
#      Waspada Hujan Lebat Tiba-tiba Yang Disertai Petir Dan Angin Kencang
#
# 34
#
# 13 November 2015
# Propinsi Kalimantan Barat
#      Waspada Hujan Yang Terjadi Berpotensi Disertai Angin Kencang Dan Guntur
#
# Selengkapnya
#
# 35
# 13 November 2015
# Propinsi Kalimantan Barat
#      Waspada Hujan Yang Terjadi Berpotensi Disertai Angin Kencang Dan Guntur
#
# 36
#
# 13 November 2015
# Propinsi Bali
#      Perlu Diwaspadai Potensi Hujan Dengan Intensitas Sedang Disertai Kilat/petir
#
# Selengkapnya
#
# 37
# 13 November 2015
# Propinsi Bali
#      Perlu Diwaspadai Potensi Hujan Dengan Intensitas Sedang Disertai Kilat/petir
#
# 38
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Dengan Intensitas Sedang-lebat Yang Disertai Kilat/petir Yang Disertai Angin Kencang Berdurasi Singkat Pada Siang-sore Hari
#
# Selengkapnya
#
# 39
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Dengan Intensitas Sedang-lebat Yang Disertai Kilat/petir Yang Disertai Angin Kencang Berdurasi Singkat Pada Siang-sore Hari
#
# 40
#
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Sedang-lebat Yang Disertai Kilat/petir Dan Angin Kencang Pada Siang-sore Hari
#
# Selengkapnya
#
# 41
# 13 November 2015
# Propinsi Banten
#      Waspada Potensi Hujan Sedang-lebat Yang Disertai Kilat/petir Dan Angin Kencang Pada Siang-sore Hari
#
# 42
# Prakiraan Cuaca
#
#
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
#
# Selengkapnya
#
#
# 43 Prakiraan Cuaca
# 44
#
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
#
# Selengkapnya
#
# 45
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
# 46 12 November 2015
# 47
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
# 48
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
# 49
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
# 50
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
# 51
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
# 52
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
# 53
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
# 54
# Bengkulu
#
# Berawan
# 25 - 32°C
#
# 55
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
# 56
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
# 57
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
# 58
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
# 59
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
# 60
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
# 61
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
# 62
# Makassar
#
# Berawan
# 26 - 34°C
#
# 63
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
# 64
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
# 65
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
# 66
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
# 67
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
# 68
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
# 69
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
# 70
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
# 71
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
# 72
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
# 73
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
# 74
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
# 75
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
# 76
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
# 77
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
# 78
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
# 79
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
# 80
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
# 81
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
# 82
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
# 83
# 84 Selengkapnya
# 85
# Informasi Iklim
#
#
#
#  Selengkapnya
#
#
# 86 Informasi Iklim
# 87
#
#
#  Selengkapnya
#
# 88
# 89  Selengkapnya
# 90
# Gempabumi Terkini
#
# 12 November 2015 - 06:36:18 WIB
#
#
#
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# Selengkapnya
#
#
# 91 Gempabumi Terkini
# 92
# 12 November 2015 - 06:36:18 WIB
#
#
#
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# Selengkapnya
#
# 93 12 November 2015 - 06:36:18 WIB
# 94
#
# 95
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 96 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# 97 Selengkapnya
# 98
# 99
#
#
#
#
#
#
#
#
#
#
#
#
#
# KULIAH UMUM RISET DAN PENGABDIAN MASYARAKAT
#
#
#
#
#
# Jumpa Pers Awal Musim Hujan `NOVEMBER, AWAL MUSIM HUJAN AKAN TIBA`
#
#
#
#
#
# WORKSHOP OPERASIONAL RADAR CUACA TAHUN 2015
#
#
#
#
#
# SEMANGAT KEPAHLAWANAN ADALAH JIWA RAGAKU
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# BERITA FOTO
#
#
#
#
#
#
# PERESMIAN BEROPERASINYA DIGITAL VIDEO BROADCAST  DI KABUPATEN SIJUNJUNG  SUMATERA BARAT
# Sijunjung, (9/11), Sebagai tindak lanjut MoU (Memorandum of Understanding) antara BMKG dengan  ...
#
#
#
#
#
#
#
# SEMINAR BULETIN MKG 2015
# TANGERANG - Selasa (3/11) bertempat di kantor BBMKG Wilayah II diadakan kegiatan SEMINAR BULETIN  ...
#
#
#
#
#
#
#
# KEPALA BMKG HADIRI PENGUKUHAN SESTAMA BMKG DI LEMHANNAS RI
# JAKARTA, Kamis(5/11/2015) - Upacara yang diikuti oleh 80 peserta Program Pendidikan Singkat  ...
#
#
# Indeks Berita
#
#
#
# ARTIKEL
#
#
#
# Mengukur Perubahan Ketebalan Lapisan Es di Puncak Soemantri, Papua New
# DYAH LUKITA SARI, S.Si, dkkPeneliti Muda Bidang Litbang Klimatologi dan Kualitas Udara BMKG
#
#
#
#
# Pemodelan Tiga Dimensi Anomali Gravitasi dan Identifikasi Sesar Lokal dalam Penentuan Jenis Sesar di Daerah Sidoarjo New
# ALEXANDER FELIX TAUFAN PARERA, dkkSPT. PMG Pelaksana Sta. Geof. Kelas III Kepahiang - Bengkulu BMKG
#
#
#
#
# Analisis Banjir Kab. Aceh Selatan
# SYAHRIRPMG Pelaksana Sta. Met. Kelas I Blang Bintang - Banda Aceh BMKG
#
#
#
#
# Memahami El Nino Secara Utuh
# WANDAYANTOLIS, S.Si., M.SiKepala Seksi Data dan Informasi Sta. Klim. Kelas I Kediri - Mataram BMKG
#
#
#
#
#
#
#
#
#
#
#           Prakiraan Cuaca
#
#
#
#
#
#
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
# Selengkapnya
#
#
#
#
#
#
#
#           Informasi Iklim
#
#
#
#
#
#
#
#  Selengkapnya
#
#
#
#
#
#
#
#           Informasi Gempabumi
#
#
#
#
#
# 12 November 2015 - 06:36:18 WIB
#
#
#
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# Selengkapnya
#
#
#
#
#
#
# 100
#
#
#
#
#
#
#
#
#
#
#
# KULIAH UMUM RISET DAN PENGABDIAN MASYARAKAT
#
#
#
#
#
# Jumpa Pers Awal Musim Hujan `NOVEMBER, AWAL MUSIM HUJAN AKAN TIBA`
#
#
#
#
#
# WORKSHOP OPERASIONAL RADAR CUACA TAHUN 2015
#
#
#
#
#
# SEMANGAT KEPAHLAWANAN ADALAH JIWA RAGAKU
#
#
#
#
#
#
# 101
#
#
#
# KULIAH UMUM RISET DAN PENGABDIAN MASYARAKAT
#
#
#
#
#
# Jumpa Pers Awal Musim Hujan `NOVEMBER, AWAL MUSIM HUJAN AKAN TIBA`
#
#
#
#
#
# WORKSHOP OPERASIONAL RADAR CUACA TAHUN 2015
#
#
#
#
#
# SEMANGAT KEPAHLAWANAN ADALAH JIWA RAGAKU
#
#
#
# 102
#
#
# KULIAH UMUM RISET DAN PENGABDIAN MASYARAKAT
#
#
# 103
# KULIAH UMUM RISET DAN PENGABDIAN MASYARAKAT
#
# 104
#
#
# Jumpa Pers Awal Musim Hujan `NOVEMBER, AWAL MUSIM HUJAN AKAN TIBA`
#
#
# 105
# Jumpa Pers Awal Musim Hujan `NOVEMBER, AWAL MUSIM HUJAN AKAN TIBA`
#
# 106
#
#
# WORKSHOP OPERASIONAL RADAR CUACA TAHUN 2015
#
#
# 107
# WORKSHOP OPERASIONAL RADAR CUACA TAHUN 2015
#
# 108
#
#
# SEMANGAT KEPAHLAWANAN ADALAH JIWA RAGAKU
#
#
# 109
# SEMANGAT KEPAHLAWANAN ADALAH JIWA RAGAKU
#
# 110
#
#
# 111
#
#
# 112
# BERITA FOTO
#
#
#
#
#
#
# PERESMIAN BEROPERASINYA DIGITAL VIDEO BROADCAST  DI KABUPATEN SIJUNJUNG  SUMATERA BARAT
# Sijunjung, (9/11), Sebagai tindak lanjut MoU (Memorandum of Understanding) antara BMKG dengan  ...
#
#
#
#
#
#
#
# SEMINAR BULETIN MKG 2015
# TANGERANG - Selasa (3/11) bertempat di kantor BBMKG Wilayah II diadakan kegiatan SEMINAR BULETIN  ...
#
#
#
#
#
#
#
# KEPALA BMKG HADIRI PENGUKUHAN SESTAMA BMKG DI LEMHANNAS RI
# JAKARTA, Kamis(5/11/2015) - Upacara yang diikuti oleh 80 peserta Program Pendidikan Singkat  ...
#
#
# Indeks Berita
#
#
# 113 BERITA FOTO
# 114
#
#
#
#
#
# PERESMIAN BEROPERASINYA DIGITAL VIDEO BROADCAST  DI KABUPATEN SIJUNJUNG  SUMATERA BARAT
# Sijunjung, (9/11), Sebagai tindak lanjut MoU (Memorandum of Understanding) antara BMKG dengan  ...
#
#
#
#
#
#
#
# SEMINAR BULETIN MKG 2015
# TANGERANG - Selasa (3/11) bertempat di kantor BBMKG Wilayah II diadakan kegiatan SEMINAR BULETIN  ...
#
#
#
#
#
#
#
# KEPALA BMKG HADIRI PENGUKUHAN SESTAMA BMKG DI LEMHANNAS RI
# JAKARTA, Kamis(5/11/2015) - Upacara yang diikuti oleh 80 peserta Program Pendidikan Singkat  ...
#
#
# Indeks Berita
#
# 115
#
#
#
#
# PERESMIAN BEROPERASINYA DIGITAL VIDEO BROADCAST  DI KABUPATEN SIJUNJUNG  SUMATERA BARAT
# Sijunjung, (9/11), Sebagai tindak lanjut MoU (Memorandum of Understanding) antara BMKG dengan  ...
#
#
# 116
# PERESMIAN BEROPERASINYA DIGITAL VIDEO BROADCAST  DI KABUPATEN SIJUNJUNG  SUMATERA BARAT
# Sijunjung, (9/11), Sebagai tindak lanjut MoU (Memorandum of Understanding) antara BMKG dengan  ...
#
# 117
#
#
#
#
# SEMINAR BULETIN MKG 2015
# TANGERANG - Selasa (3/11) bertempat di kantor BBMKG Wilayah II diadakan kegiatan SEMINAR BULETIN  ...
#
#
# 118
# SEMINAR BULETIN MKG 2015
# TANGERANG - Selasa (3/11) bertempat di kantor BBMKG Wilayah II diadakan kegiatan SEMINAR BULETIN  ...
#
# 119
#
#
#
#
# KEPALA BMKG HADIRI PENGUKUHAN SESTAMA BMKG DI LEMHANNAS RI
# JAKARTA, Kamis(5/11/2015) - Upacara yang diikuti oleh 80 peserta Program Pendidikan Singkat  ...
#
#
# 120
# KEPALA BMKG HADIRI PENGUKUHAN SESTAMA BMKG DI LEMHANNAS RI
# JAKARTA, Kamis(5/11/2015) - Upacara yang diikuti oleh 80 peserta Program Pendidikan Singkat  ...
#
# 121 Indeks Berita
# 122
# ARTIKEL
#
#
#
# Mengukur Perubahan Ketebalan Lapisan Es di Puncak Soemantri, Papua New
# DYAH LUKITA SARI, S.Si, dkkPeneliti Muda Bidang Litbang Klimatologi dan Kualitas Udara BMKG
#
#
#
#
# Pemodelan Tiga Dimensi Anomali Gravitasi dan Identifikasi Sesar Lokal dalam Penentuan Jenis Sesar di Daerah Sidoarjo New
# ALEXANDER FELIX TAUFAN PARERA, dkkSPT. PMG Pelaksana Sta. Geof. Kelas III Kepahiang - Bengkulu BMKG
#
#
#
#
# Analisis Banjir Kab. Aceh Selatan
# SYAHRIRPMG Pelaksana Sta. Met. Kelas I Blang Bintang - Banda Aceh BMKG
#
#
#
#
# Memahami El Nino Secara Utuh
# WANDAYANTOLIS, S.Si., M.SiKepala Seksi Data dan Informasi Sta. Klim. Kelas I Kediri - Mataram BMKG
#
#
#
#
# 123 ARTIKEL
# 124
#
#
# Mengukur Perubahan Ketebalan Lapisan Es di Puncak Soemantri, Papua New
# DYAH LUKITA SARI, S.Si, dkkPeneliti Muda Bidang Litbang Klimatologi dan Kualitas Udara BMKG
#
#
#
#
# Pemodelan Tiga Dimensi Anomali Gravitasi dan Identifikasi Sesar Lokal dalam Penentuan Jenis Sesar di Daerah Sidoarjo New
# ALEXANDER FELIX TAUFAN PARERA, dkkSPT. PMG Pelaksana Sta. Geof. Kelas III Kepahiang - Bengkulu BMKG
#
#
#
#
# Analisis Banjir Kab. Aceh Selatan
# SYAHRIRPMG Pelaksana Sta. Met. Kelas I Blang Bintang - Banda Aceh BMKG
#
#
#
#
# Memahami El Nino Secara Utuh
# WANDAYANTOLIS, S.Si., M.SiKepala Seksi Data dan Informasi Sta. Klim. Kelas I Kediri - Mataram BMKG
#
#
#
# 125
#
# Mengukur Perubahan Ketebalan Lapisan Es di Puncak Soemantri, Papua New
# DYAH LUKITA SARI, S.Si, dkkPeneliti Muda Bidang Litbang Klimatologi dan Kualitas Udara BMKG
#
#
# 126
#
# Pemodelan Tiga Dimensi Anomali Gravitasi dan Identifikasi Sesar Lokal dalam Penentuan Jenis Sesar di Daerah Sidoarjo New
# ALEXANDER FELIX TAUFAN PARERA, dkkSPT. PMG Pelaksana Sta. Geof. Kelas III Kepahiang - Bengkulu BMKG
#
#
# 127
#
# Analisis Banjir Kab. Aceh Selatan
# SYAHRIRPMG Pelaksana Sta. Met. Kelas I Blang Bintang - Banda Aceh BMKG
#
#
# 128
#
# Memahami El Nino Secara Utuh
# WANDAYANTOLIS, S.Si., M.SiKepala Seksi Data dan Informasi Sta. Klim. Kelas I Kediri - Mataram BMKG
#
#
# 129
#
#
#
#
#           Prakiraan Cuaca
#
#
#
#
#
#
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
# Selengkapnya
#
#
#
#
#
#
#
#           Informasi Iklim
#
#
#
#
#
#
#
#  Selengkapnya
#
#
#
#
#
#
#
#           Informasi Gempabumi
#
#
#
#
#
# 12 November 2015 - 06:36:18 WIB
#
#
#
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# Selengkapnya
#
#
#
#
# 130
#
#
#
#           Prakiraan Cuaca
#
#
#
#
#
#
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
# Selengkapnya
#
#
#
# 131
#
#
#           Prakiraan Cuaca
#
#
#
# 132
#
#
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
# Selengkapnya
#
#
# 133
#
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
# Selengkapnya
#
# 134
# 12 November 2015
#
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
#
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
#
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
#
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
#
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
#
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
#
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
#
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
#
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
#
# 135 12 November 2015
# 136
#
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
#
# 137
#
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
#
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
#
# 138
# Medan
#
# Hujan Sedang
# 23 - 32°C
#
# 139 Hujan Sedang
# 140 23 - 32°C
# 141
# Padang
#
# Hujan Ringan
# 22 - 30°C
#
# 142 Hujan Ringan
# 143 22 - 30°C
# 144
#
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
#
# 145
#
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
#
# Bengkulu
#
# Berawan
# 25 - 32°C
#
#
# 146
# Palembang
#
# Hujan Ringan
# 24 - 34°C
#
# 147 Hujan Ringan
# 148 24 - 34°C
# 149
# Bengkulu
#
# Berawan
# 25 - 32°C
#
# 150 Berawan
# 151 25 - 32°C
# 152
#
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
#
# 153
#
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
#
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
#
# 154
# Pontianak
#
# Hujan Ringan
# 24 - 32°C
#
# 155 Hujan Ringan
# 156 24 - 32°C
# 157
# Palangkaraya
#
# Hujan Sedang
# 21 - 34°C
#
# 158 Hujan Sedang
# 159 21 - 34°C
# 160
#
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
#
# 161
#
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
#
# Makassar
#
# Berawan
# 26 - 34°C
#
#
# 162
# Manado
#
# Hujan Ringan
# 22 - 30°C
#
# 163 Hujan Ringan
# 164 22 - 30°C
# 165
# Makassar
#
# Berawan
# 26 - 34°C
#
# 166 Berawan
# 167 26 - 34°C
# 168
#
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
#
# 169
#
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
#
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
#
# 170
# Ternate
#
# Hujan Ringan
# 23 - 31°C
#
# 171 Hujan Ringan
# 172 23 - 31°C
# 173
# Ambon
#
# Cerah Berawan
# 24 - 33°C
#
# 174 Cerah Berawan
# 175 24 - 33°C
# 176
#
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
#
# 177
#
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
#
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
#
# 178
# Jayapura
#
# Hujan Ringan
# 24 - 33°C
#
# 179 Hujan Ringan
# 180 24 - 33°C
# 181
# Sorong
#
# Hujan Ringan
# 24 - 31°C
#
# 182 Hujan Ringan
# 183 24 - 31°C
# 184
#
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
#
# 185
#
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
#
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
#
# 186
# Kupang
#
# Hujan Ringan
# 25 - 34°C
#
# 187 Hujan Ringan
# 188 25 - 34°C
# 189
# Denpasar
#
# Hujan Ringan
# 24 - 32°C
#
# 190 Hujan Ringan
# 191 24 - 32°C
# 192
#
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
#
# 193
#
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
#
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
#
# 194
# Jakarta
#
# Hujan Sedang
# 26 - 32°C
#
# 195 Hujan Sedang
# 196 26 - 32°C
# 197
# Bandung
#
# Hujan Sedang
# 20 - 30°C
#
# 198 Hujan Sedang
# 199 20 - 30°C
# 200
#
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
#
# 201
#
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
#
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
#
# 202
# Semarang
#
# Hujan Ringan
# 25 - 33°C
#
# 203 Hujan Ringan
# 204 25 - 33°C
# 205
# Surabaya
#
# Hujan Ringan
# 25 - 34°C
#
# 206 Hujan Ringan
# 207 25 - 34°C
# 208 Selengkapnya
# 209
#
#
#
#           Informasi Iklim
#
#
#
#
#
#
#
#  Selengkapnya
#
#
#
# 210
#
#
#           Informasi Iklim
#
#
#
# 211
#
#
#
#  Selengkapnya
#
#
# 212
#
#
#  Selengkapnya
#
# 213
# 214  Selengkapnya
# 215
#
#
#
#           Informasi Gempabumi
#
#
#
#
#
# 12 November 2015 - 06:36:18 WIB
#
#
#
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# Selengkapnya
#
#
#
# 216
#
#
#           Informasi Gempabumi
#
#
#
# 217
#
# 12 November 2015 - 06:36:18 WIB
#
#
#
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# Selengkapnya
#
#
# 218
# 12 November 2015 - 06:36:18 WIB
#
#
#
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# Selengkapnya
#
# 219 12 November 2015 - 06:36:18 WIB
# 220
#
# 221
# 				Lokasi :7.45 LS - 129.12 BT
# 				Kedalaman : 148 Km
#
# 222 250 km BaratLaut MALUKUTENGGARABRTtidak berpotensi TSUNAMI
# 223 Selengkapnya
# 224
#
# Banner Layanan
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
#
#
#
#
#
#
#
#
#
#
# Media
#
# Rabu, 02 September 2015
# Tutorial Login ePUPNS
#
#
#
# 			jwplayer("myElement").setup({
# 			  file: "http://media.bmkg.go.id/media/LOGIN_ePUPNS_20159210290.mp4",
# 			  image: "http://media.bmkg.go.id/imagesdata/BMKG-VOD_20159211117.jpg",
# 			  width: "100%",
# 			  aspectratio: "16:9"
# 			});
#
# Tutorial Login  ...   [46.82 MB]
#
#
#
# Pidato Kepala BMKG
#
#
#
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 12/05
#
#
#
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 23/03
#
#
#
# IPCC Regional Outreach Working Group II And III  ...
# 11/07
#
#
#
# Pembukaan Rapat Rekonsiliasi Laporan Keuangan  ...
# 05/07
#
#
#
#
#
# Pengumuman
#
#
#
#
# Vacancy Notice No.1942 WMO
#
#
#
#
# Beasiswa S2 dan S3 NOAA
#
#
#
#
# Vacancy Notice No. 1941 WMO
#
#
#
# Indeks Pengumuman
#
#
#
# 225
# Banner Layanan
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
#
#
#
#
#
#
#
# 226 Banner Layanan
# 227
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
#
#
#
#
#
#
# 228
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
#
#
# 229
#
#
#
#
#
#
#
#
#
#
# 230
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
#
# 231
# 1
# 2
# 3
# 4
# 5
# 6
#
#
# 232
#
#
# Media
#
# Rabu, 02 September 2015
# Tutorial Login ePUPNS
#
#
#
# 			jwplayer("myElement").setup({
# 			  file: "http://media.bmkg.go.id/media/LOGIN_ePUPNS_20159210290.mp4",
# 			  image: "http://media.bmkg.go.id/imagesdata/BMKG-VOD_20159211117.jpg",
# 			  width: "100%",
# 			  aspectratio: "16:9"
# 			});
#
# Tutorial Login  ...   [46.82 MB]
#
#
# 233 Media
# 234
# Rabu, 02 September 2015
# Tutorial Login ePUPNS
#
#
#
# 			jwplayer("myElement").setup({
# 			  file: "http://media.bmkg.go.id/media/LOGIN_ePUPNS_20159210290.mp4",
# 			  image: "http://media.bmkg.go.id/imagesdata/BMKG-VOD_20159211117.jpg",
# 			  width: "100%",
# 			  aspectratio: "16:9"
# 			});
#
# Tutorial Login  ...   [46.82 MB]
#
# 235
# 236
# 237
# Pidato Kepala BMKG
#
#
#
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 12/05
#
#
#
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 23/03
#
#
#
# IPCC Regional Outreach Working Group II And III  ...
# 11/07
#
#
#
# Pembukaan Rapat Rekonsiliasi Laporan Keuangan  ...
# 05/07
#
#
#
#
# 238 Pidato Kepala BMKG
# 239
#
#
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 12/05
#
#
#
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 23/03
#
#
#
# IPCC Regional Outreach Working Group II And III  ...
# 11/07
#
#
#
# Pembukaan Rapat Rekonsiliasi Laporan Keuangan  ...
# 05/07
#
#
#
# 240
#
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 12/05
#
#
#
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 23/03
#
#
#
# IPCC Regional Outreach Working Group II And III  ...
# 11/07
#
#
#
# Pembukaan Rapat Rekonsiliasi Laporan Keuangan  ...
# 05/07
#
#
# 241
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 12/05
#
# 242 Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 243 12/05
# 244
# Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 23/03
#
# 245 Sambutan Kepala Badan Meteorologi, Klimatologi,  ...
# 246 23/03
# 247
# IPCC Regional Outreach Working Group II And III  ...
# 11/07
#
# 248 IPCC Regional Outreach Working Group II And III  ...
# 249 11/07
# 250
# Pembukaan Rapat Rekonsiliasi Laporan Keuangan  ...
# 05/07
#
# 251 Pembukaan Rapat Rekonsiliasi Laporan Keuangan  ...
# 252 05/07
# 253
# Pengumuman
#
#
#
#
# Vacancy Notice No.1942 WMO
#
#
#
#
# Beasiswa S2 dan S3 NOAA
#
#
#
#
# Vacancy Notice No. 1941 WMO
#
#
#
# Indeks Pengumuman
#
#
# 254 Pengumuman
# 255
#
#
#
# Vacancy Notice No.1942 WMO
#
#
#
#
# Beasiswa S2 dan S3 NOAA
#
#
#
#
# Vacancy Notice No. 1941 WMO
#
#
#
# Indeks Pengumuman
#
# 256
#
#
# Vacancy Notice No.1942 WMO
#
#
#
#
# Beasiswa S2 dan S3 NOAA
#
#
#
#
# Vacancy Notice No. 1941 WMO
#
#
#
# 257
# Vacancy Notice No.1942 WMO
#
#
# 258 Vacancy Notice No.1942 WMO
# 259
# Beasiswa S2 dan S3 NOAA
#
#
# 260 Beasiswa S2 dan S3 NOAA
# 261
# Vacancy Notice No. 1941 WMO
#
#
# 262 Vacancy Notice No. 1941 WMO
# 263 Indeks Pengumuman
# 264
#
# 265
#
#
#
# Prakiraan Angin
#
#
#
#
#
# Informasi Iklim
#
#
#
#
#
# Potensi Kebakaran Hutan
#
#
#
#
#
# Citra Radar
#
#
#
#
#
#
#
#
# ×
# Prakiraan Angin
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
#
#
#
#
#
#
# ×
# Informasi Iklim
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
#
#
#
#
#
#
# ×
# Informasi Kebakaran Hutan
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
#
#
#
#
#
#
# ×
# Citra Radar
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
#
#
#
#
#
#
# Follow @infoBMKG
# !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
#
# (function(d, s, id) {
# 		  var js, fjs = d.getElementsByTagName(s)[0];
# 		  if (d.getElementById(id)) return;
# 		  js = d.createElement(s); js.id = id;
# 		  js.src = "//connect.facebook.net/id_ID/sdk.js#xfbml=1&appId=160060267407310&version=v2.0";
# 		  fjs.parentNode.insertBefore(js, fjs);
# 		}(document, 'script', 'facebook-jssdk'));
#
#
#
#
#
#
# 			  window.___gcfg = {lang: 'id'};
#
# 			  (function() {
# 				var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# 				po.src = 'https://apis.google.com/js/platform.js';
# 				var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# 			  })();
#
#
#
#
#
#
# 266
#
#
# Prakiraan Angin
#
#
#
#
#
# Informasi Iklim
#
#
#
#
#
# Potensi Kebakaran Hutan
#
#
#
#
#
# Citra Radar
#
#
#
#
#
#
#
#
# ×
# Prakiraan Angin
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
#
#
#
#
#
#
# ×
# Informasi Iklim
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
#
#
#
#
#
#
# ×
# Informasi Kebakaran Hutan
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
#
#
#
#
#
#
# ×
# Citra Radar
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
#
#
# 267
#
# Prakiraan Angin
#
#
#
# 268
# Prakiraan Angin
#
#
# 269 Prakiraan Angin
# 270
#
# Informasi Iklim
#
#
#
# 271
# Informasi Iklim
#
#
# 272 Informasi Iklim
# 273
#
# Potensi Kebakaran Hutan
#
#
#
# 274
# Potensi Kebakaran Hutan
#
#
# 275 Potensi Kebakaran Hutan
# 276
#
# Citra Radar
#
#
#
# 277
# Citra Radar
#
#
# 278 Citra Radar
# 279
#
#
#
# ×
# Prakiraan Angin
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
# 280
#
#
# ×
# Prakiraan Angin
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
# 281
#
# ×
# Prakiraan Angin
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
# 282
# ×
# Prakiraan Angin
#
# 283
#
#
# 284
# Tutup
# Lihat Informasi
#
# 285
#
#
#
# ×
# Informasi Iklim
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
# 286
#
#
# ×
# Informasi Iklim
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
# 287
#
# ×
# Informasi Iklim
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
# 288
# ×
# Informasi Iklim
#
# 289
#
#
# 290
# Tutup
# Lihat Informasi
#
# 291
#
#
#
# ×
# Informasi Kebakaran Hutan
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
# 292
#
#
# ×
# Informasi Kebakaran Hutan
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
# 293
#
# ×
# Informasi Kebakaran Hutan
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
# 294
# ×
# Informasi Kebakaran Hutan
#
# 295
#
#
# 296
# Tutup
# Lihat Informasi
#
# 297
#
#
#
# ×
# Citra Radar
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
# 298
#
#
# ×
# Citra Radar
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
# 299
#
# ×
# Citra Radar
#
#
#
#
#
# Tutup
# Lihat Informasi
#
#
# 300
# ×
# Citra Radar
#
# 301
#
#
# 302
# Tutup
# Lihat Informasi
#
# 303
#
#
#
# Follow @infoBMKG
# !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
#
# (function(d, s, id) {
# 		  var js, fjs = d.getElementsByTagName(s)[0];
# 		  if (d.getElementById(id)) return;
# 		  js = d.createElement(s); js.id = id;
# 		  js.src = "//connect.facebook.net/id_ID/sdk.js#xfbml=1&appId=160060267407310&version=v2.0";
# 		  fjs.parentNode.insertBefore(js, fjs);
# 		}(document, 'script', 'facebook-jssdk'));
#
#
#
#
#
#
# 			  window.___gcfg = {lang: 'id'};
#
# 			  (function() {
# 				var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# 				po.src = 'https://apis.google.com/js/platform.js';
# 				var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# 			  })();
#
#
#
#
#
# 304
#
#
# Follow @infoBMKG
# !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
#
# (function(d, s, id) {
# 		  var js, fjs = d.getElementsByTagName(s)[0];
# 		  if (d.getElementById(id)) return;
# 		  js = d.createElement(s); js.id = id;
# 		  js.src = "//connect.facebook.net/id_ID/sdk.js#xfbml=1&appId=160060267407310&version=v2.0";
# 		  fjs.parentNode.insertBefore(js, fjs);
# 		}(document, 'script', 'facebook-jssdk'));
#
#
#
#
#
#
# 			  window.___gcfg = {lang: 'id'};
#
# 			  (function() {
# 				var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# 				po.src = 'https://apis.google.com/js/platform.js';
# 				var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# 			  })();
#
#
#
#
# 305
#
# Follow @infoBMKG
# !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
#
# (function(d, s, id) {
# 		  var js, fjs = d.getElementsByTagName(s)[0];
# 		  if (d.getElementById(id)) return;
# 		  js = d.createElement(s); js.id = id;
# 		  js.src = "//connect.facebook.net/id_ID/sdk.js#xfbml=1&appId=160060267407310&version=v2.0";
# 		  fjs.parentNode.insertBefore(js, fjs);
# 		}(document, 'script', 'facebook-jssdk'));
#
#
#
#
#
#
# 			  window.___gcfg = {lang: 'id'};
#
# 			  (function() {
# 				var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# 				po.src = 'https://apis.google.com/js/platform.js';
# 				var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# 			  })();
#
#
#
# 306
# Follow @infoBMKG
# !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#
# 307
# 308
#
#
# 309
# 310
#
#
# 			  window.___gcfg = {lang: 'id'};
#
# 			  (function() {
# 				var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# 				po.src = 'https://apis.google.com/js/platform.js';
# 				var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# 			  })();
#
#
# 311
# 312
#
#
#
# ×
# Informasi Gempabumi Terkini
#
#
#
#
#
# 12 November 2015 06:36:18 WIB
# Magnitudo :
# Lokasi: 7.45 LS - 129.12 BT
#
#
# 250 km BaratLaut MALUKUTENGGARABRT
# 304 km TimurLaut MALUKUBRTDAYA
# 441 km BaratDaya MALUKUTENGGARA
# 434 km Tenggara AMBON-MALUKU
# 2481 km Tenggara JAKARTA-INDONESIA
#
#
# Kedalaman : 148 Km
# tidak berpotensi TSUNAMI
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
#
# 313
#
#
# ×
# Informasi Gempabumi Terkini
#
#
#
#
#
# 12 November 2015 06:36:18 WIB
# Magnitudo :
# Lokasi: 7.45 LS - 129.12 BT
#
#
# 250 km BaratLaut MALUKUTENGGARABRT
# 304 km TimurLaut MALUKUBRTDAYA
# 441 km BaratDaya MALUKUTENGGARA
# 434 km Tenggara AMBON-MALUKU
# 2481 km Tenggara JAKARTA-INDONESIA
#
#
# Kedalaman : 148 Km
# tidak berpotensi TSUNAMI
#
#
#
#
# Tutup
# Lihat Informasi
#
#
#
# 314
#
# ×
# Informasi Gempabumi Terkini
#
#
#
#
#
# 12 November 2015 06:36:18 WIB
# Magnitudo :
# Lokasi: 7.45 LS - 129.12 BT
#
#
# 250 km BaratLaut MALUKUTENGGARABRT
# 304 km TimurLaut MALUKUBRTDAYA
# 441 km BaratDaya MALUKUTENGGARA
# 434 km Tenggara AMBON-MALUKU
# 2481 km Tenggara JAKARTA-INDONESIA
#
#
# Kedalaman : 148 Km
# tidak berpotensi TSUNAMI
#
#
#
#
# Tutup
# Lihat Informasi
#
#
# 315
# ×
# Informasi Gempabumi Terkini
#
# 316
#
#
#
# 12 November 2015 06:36:18 WIB
# Magnitudo :
# Lokasi: 7.45 LS - 129.12 BT
#
#
# 250 km BaratLaut MALUKUTENGGARABRT
# 304 km TimurLaut MALUKUBRTDAYA
# 441 km BaratDaya MALUKUTENGGARA
# 434 km Tenggara AMBON-MALUKU
# 2481 km Tenggara JAKARTA-INDONESIA
#
#
# Kedalaman : 148 Km
# tidak berpotensi TSUNAMI
#
#
#
# 317 12 November 2015 06:36:18 WIB
# 318 Magnitudo :
# 319 Lokasi: 7.45 LS - 129.12 BT
# 320
#
# 250 km BaratLaut MALUKUTENGGARABRT
# 304 km TimurLaut MALUKUBRTDAYA
# 441 km BaratDaya MALUKUTENGGARA
# 434 km Tenggara AMBON-MALUKU
# 2481 km Tenggara JAKARTA-INDONESIA
#
#
# 321 Kedalaman : 148 Km
# 322 tidak berpotensi TSUNAMI
# 323
# Tutup
# Lihat Informasi
